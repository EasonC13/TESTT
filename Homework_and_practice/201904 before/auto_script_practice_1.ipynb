# %% [markdown]
# 練習做外掛
# <br/>
# 參考這邊： https://www.itread01.com/article/1515052484.html

# %%
import autopy
autopy.mouse.move(900, 100) # 移動滑鼠
autopy.mouse.smooth_move(400, 400) # 平滑移動滑鼠（上面那個是瞬間的）

# %%
import time

# %%
time.sleep(10)

# %%
def get_hash(self, img):
   #使用PIL模組縮放圖片,***
    image = img.resize((18, 13), Image.ANTIALIAS).convert("L")
    pixels = list(image.getdata())
    avg = sum(pixels) / len(pixels)
    return "".join(map(lambda p : "1" if p > avg else "0", pixels))

# %%
import time
import numpy as np
from PIL import ImageGrab
from PIL import Image
from selenium import webdriver
import time

# %%
from selenium import webdriver
import time

# %%
import time
import win32gui, win32ui, win32con, win32api
def window_capture(filename):
    hwnd = 0 # 視窗的編號，0號表示當前活躍視窗
# 根據視窗控制代碼獲取視窗的裝置上下文DC（Divice Context）
    hwndDC = win32gui.GetWindowDC(hwnd)
# 根據視窗的DC獲取mfcDC
    mfcDC = win32ui.CreateDCFromHandle(hwndDC)
# mfcDC建立可相容的DC
    saveDC = mfcDC.CreateCompatibleDC()
# 建立bigmap準備儲存圖片
    saveBitMap = win32ui.CreateBitmap()
# 獲取監控器資訊
    MoniterDev = win32api.EnumDisplayMonitors(None, None)
    w = MoniterDev[0][2][2]
    h = MoniterDev[0][2][3]
# print w,h　　　#圖片大小
# 為bitmap開闢空間
    saveBitMap.CreateCompatibleBitmap(mfcDC, w, h)
# 高度saveDC，將截圖儲存到saveBitmap中
    saveDC.SelectObject(saveBitMap)
# 擷取從左上角（0，0）長寬為（w，h）的圖片
    saveDC.BitBlt((0, 0), (w, h), mfcDC, (0, 0), win32con.SRCCOPY)
    saveBitMap.SaveBitmapFile(saveDC, filename)
    window_capture("haha.jpg")
    print(w,h)

# %%
a=open('haha.jpg')

# %%
import matplotlib.pyplot as plt
import sys
import win32gui
import win32ui
import win32con
from time import sleep
from datetime import datetime

# %%
type(a)
# Out:
# _io.TextIOWrapper

# %%
window_capture('a')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-2005373f356a> in <module>()
# ----> 1 window_capture('a')
#
# <ipython-input-7-64e55caf703f> in window_capture(filename)
#      23     saveDC.BitBlt((0, 0), (w, h), mfcDC, (0, 0), win32con.SRCCOPY)
#      24     saveBitMap.SaveBitmapFile(saveDC, filename)
# ---> 25     window_capture("haha.jpg")
#      26     print(w,h)
#
# <ipython-input-7-64e55caf703f> in window_capture(filename)
#      22 # 擷取從左上角（0，0）長寬為（w，h）的圖片
#      23     saveDC.BitBlt((0, 0), (w, h), mfcDC, (0, 0), win32con.SRCCOPY)
# ---> 24     saveBitMap.SaveBitmapFile(saveDC, filename)
#      25     window_capture("haha.jpg")
#      26     print(w,h)
#
# error: CreateFile

# %%
window_capture("hahaha.jpg")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-b3612ca0b8eb> in <module>()
# ----> 1 window_capture("hahaha.jpg")
#
# <ipython-input-7-64e55caf703f> in window_capture(filename)
#      23     saveDC.BitBlt((0, 0), (w, h), mfcDC, (0, 0), win32con.SRCCOPY)
#      24     saveBitMap.SaveBitmapFile(saveDC, filename)
# ---> 25     window_capture("haha.jpg")
#      26     print(w,h)
#
# <ipython-input-7-64e55caf703f> in window_capture(filename)
#      22 # 擷取從左上角（0，0）長寬為（w，h）的圖片
#      23     saveDC.BitBlt((0, 0), (w, h), mfcDC, (0, 0), win32con.SRCCOPY)
# ---> 24     saveBitMap.SaveBitmapFile(saveDC, filename)
#      25     window_capture("haha.jpg")
#      26     print(w,h)
#
# error: CreateFile

# %%
def screenshot(hwnd, filename):
    procHandle = win32gui.FindWindow(None, "開啟")
    hwnd=procHandle
    time.sleep(1)
    l,t,r,b = win32gui.GetClientRect(hwnd)
    h = b - t
    w = r - l
    hDC = win32gui.GetDC(hwnd)
    myDC = win32ui.CreateDCFromHandle(hDC)
    newDC = myDC.CreateCompatibleDC()

    myBitMap = win32ui.CreateBitmap()
    myBitMap.CreateCompatibleBitmap(myDC, w, h)

    newDC.SelectObject(myBitMap)

    win32gui.SetForegroundWindow(hwnd)
    sleep(.2) #lame way to allow screen to draw before taking shot
    newDC.BitBlt((0,0),(w, h) , myDC, (0,0), win32con.SRCCOPY)
    myBitMap.Paint(newDC)
    myBitMap.SaveBitmapFile(newDC, "c:\\bla.bmp")

# %%
screenshot(1,'hi')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-32-5f1965e8a3ba> in <module>()
# ----> 1 screenshot(1,'hi')
#
# <ipython-input-31-01b0c878b638> in screenshot(hwnd, filename)
#       3     hwnd=procHandle
#       4     time.sleep(1)
# ----> 5     l,t,r,b = win32gui.GetClientRect(hwnd)
#       6     h = b - t
#       7     w = r - l
#
# error: (1400, 'GetClientRect', '無效的視窗控制代碼。')

# %%
from PIL import ImageGrab
import win32gui

hwnd = win32gui.FindWindow(None, r'Window_Title')
win32gui.SetForegroundWindow(int(hwnd))
dimensions = win32gui.GetWindowRect(hwnd)

image = ImageGrab.grab(dimensions)
image.show()

# %%
hwnd

# %%
from PIL import ImageGrab
im=ImageGrab.grab(bbox=(300,100,1000,1000))
im
# Out:
# <PIL.Image.Image image mode=RGB size=700x900 at 0x21D77941198>

# %%
width = im.size[0]  # 图片大小
height = im.size[1]
im.crop((
        width - 200,
        height - 200,
        width,
        height
    ))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x21D77958048>

# %%
im

# %%
def Screenshot_1_result():
#from PIL import ImageGrab
    im=ImageGrab.grab(bbox=(300,100,1000,1000))
    width = 410  # 图片大小
    height = 250
    im=im.crop((
            width - 90,
            height - 160,
            width,
            height-60))
    return im

# %%
Screenshot_1_result()

# %%
type(im)

# %%
import autopy
time.sleep(1)
autopy.mouse.click() # 單擊
autopy.mouse.toggle(True) # 按下左鍵
autopy.mouse.toggle(False) # 鬆開左鍵
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-58a12de8d8c0> in <module>()
#       2 time.sleep(1)
#       3 autopy.mouse.click() # 單擊
# ----> 4 autopy.mouse.toggle(True) # 按下左鍵
#       5 autopy.mouse.toggle(False) # 鬆開左鍵
#
# TypeError: Required argument ('down') (pos 2) not found

# %%
MousePos = MouseGetPos()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-68e87f0553b2> in <module>()
# ----> 1 MousePos = MouseGetPos()
#
# NameError: name 'MouseGetPos' is not defined

# %%
import autopy
def hello_world():
    autopy.alert.alert("Hello, world")
hello_world()

# %%
if autopy.alert.alert('Hi'):
    print("Done")
# Out:
# Done

# %%
autopy.mouse.move(100, 100)

# %%
imss=open('')

# %%
type(imss)
# Out:
# _io.TextIOWrapper

# %%
imgaa=Image.open('pos1.png')

# %%
np.array(imgaa).sum()
# Out:
# 2223021

# %%
aaa=np.array(imgaa)

# %%
plt.imshow(aaa)

# %%
imgaa
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=90x100 at 0x1D3FE6FEE80>

# %% [markdown]
# 以下為訓練模型

# %%
import time
import numpy as np
from PIL import ImageGrab
from PIL import Image
from selenium import webdriver
import time

# %%
img=[]
for i in range(5):
    filename=list('pos0.jpg')
    filename[3]=str(i)
    filename=''.join(filename)
    img.append(Image.open(filename))

# %%
img=[]
for i in range(1,4):
    filename=list('pos0.jpg')
    filename[3]=str(i)
    filename=''.join(filename)
    img.append(Image.open(filename))

# %%
img[1]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=90x100 at 0x21D6FB8D080>

# %%
for i in range(3):
    img[i]=np.array(img[i])

# %%
img=np.array(img)

# %%
img.shape
# Out:
# (3, 100, 90, 3)

# %%
img=img.reshape(-1,27000)

# %%
img.shape
# Out:
# (3, 27000)

# %%
filename
# Out:
# 'pos3.jpg'

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
ans=np.array([0,1,2])
ans=ans.reshape(-1)

# %%
ans
# Out:
# array([0, 1, 2])

# %%
ans=np_utils.to_categorical(ans,3)

# %%
ans
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
model.add(Dense(50,input_dim=27000)) #第一層有50個
model.add(Activation('relu')) #第一層用sigmod
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.add(Dense(25)) #第一層有50個
model.add(Activation('relu')) #第一層用sigmod

# %%
model.add(Dense(10)) #第一層有50個
model.add(Activation('relu')) #第一層用sigmod

# %%
model.add(Dense(3))
model.add(Activation('softmax'))

# %%
model.compile(loss='mse', optimizer=SGD(lr=0.087), metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 50)                1350050
# _________________________________________________________________
# activation_1 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                1275
# _________________________________________________________________
# activation_2 (Activation)    (None, 25)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                260
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 33
# _________________________________________________________________
# activation_4 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 1,351,618
# Trainable params: 1,351,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
img
# Out:
# array([[ 51,  51,  51, ..., 150,  44,  66],
#        [ 36,  79, 157, ...,  51,  51,  51],
#        [ 59, 114,  33, ...,  60, 115,  34]], dtype=uint8)

# %%
model.fit(img, ans, batch_size=4, epochs=10)
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 3/3 [==============================] - 0s 144ms/step - loss: 0.3894 - acc: 0.3333
# Epoch 2/10
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 3/10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 4/10
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 5/10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 6/10
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 7/10
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 8/10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 9/10
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4444 - acc: 0.3333
# Epoch 10/10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4444 - acc: 0.3333

# %%
predict = model.predict_classes(img)

# %%
predict
# Out:
# array([2, 2, 2], dtype=int64)

# %%
ans
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
print('怡升好帥')
for i in range(5):
    time.sleep(1)
    print('好啦我知道了',i,end='')
    print('\r',end='')
# Out:
# 怡升好帥
# 好啦我知道了 4

# %%
import sys,time
for i in range(10):
    print('#',end='',flush=False)
    time.sleep(0.4)
# Out:
# ##########

# %%
a=input('請按任意鍵繼續')
# Out:
# 請按任意鍵繼續
