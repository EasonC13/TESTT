# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("C:/Users/user\Downloads\AI-Tutorial-Multiple-Linear-Regression-master/stu.csv")

# %%
df.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
math=np.array(df.Math)
math=math.reshape(len(math))
math
# Out:
# array([ 48,  62,  79,  76,  59,  69,  70,  46,  61,  86,  62,  72,  56,
#         81,  61,  49,  60,  45,  71,  75,  66,  57,  67,  63,  68,  68,
#         62,  56,  82,  64,  71,  69,  64,  76,  61,  47,  50,  75,  69,
#         42,  73,  78,  65,  51,  61,  69,  51,  64,  90,  58, 100,  73,
#         62,  45,  47,  53,  62,  49,  77,  70,  60,  82, 100,  72,  62,
#         87,  56,  96,  68,  66,  68,  59,  52,  60,  60,  46,  62,  30,
#         83,  69,  82,  64,  57,  71,  37,  69,  72,  73,  70,  75,  54,
#         71,  60,  81,  58,  54,  49,  64,  84,  84], dtype=int64)

# %%
read=np.array(df.Reading)
read=read.reshape(len(read))

# %%
write=np.array(df.Writing)
write=write.reshape(len(write))
np.shape(write)
# Out:
# (100,)

# %%
read=read.reshape(-1, 1)
math=math.reshape(len(math),1)

# %%
m_train,m_test,r_train,r_test,w_train,w_test=train_test_split(math,read,write,test_size=0.1,random_state=87)

# %%
f=LinearRegression()

# %%
f.fit(m_train,r_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
result=f.predict(m_test)

# %%
plt.plot(m_test,result)
plt.scatter(m_test,r_test)

# %%
result=f.predict(m_test[5][0])

# %%
result
# Out:
# array([[71.94014242]])

# %%
r_test[5][0]
# Out:
# 90

# %%
df=pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=87672&md5_url=6ce52dac47e37a1643be4b22e51afe29')

# %%
df.head()
# Out:
#   observeDate observatory dataLose rainfall
# 0     2015-09       茶業改良場      NaN    300.5
# 1     2015-10       茶業改良場        ＊    105.5
# 2     2015-11       茶業改良場        ＊       28
# 3     2015-12       茶業改良場      NaN     92.5
# 4     2016-01       茶業改良場      NaN    352.5

# %%
df['time'] = pd.to_datetime(df['observeDate'])

# %%
df.head()
# Out:
#   observeDate observatory dataLose rainfall       time
# 0     2015-09       茶業改良場      NaN    300.5 2015-09-01
# 1     2015-10       茶業改良場        ＊    105.5 2015-10-01
# 2     2015-11       茶業改良場        ＊       28 2015-11-01
# 3     2015-12       茶業改良場      NaN     92.5 2015-12-01
# 4     2016-01       茶業改良場      NaN    352.5 2016-01-01

# %%
df=df.sort_values('time')

# %%
df
# Out:
#     observeDate observatory dataLose rainfall       time
# 0       2015-09       茶業改良場      NaN    300.5 2015-09-01
# 240     2015-09        雲林分場        ＊    241.5 2015-09-01
# 24      2015-09       義竹工作站      NaN      383 2015-09-01
# 288     2015-09          東港      NaN        0 2015-09-01
# 48      2015-09       高雄農改場      NaN    111.5 2015-09-01
# 264     2015-09       畜產試驗所      NaN    205.5 2015-09-01
# 120     2015-09       五峰工作站      NaN    330.5 2015-09-01
# 216     2015-09       溪頭營林區      NaN        0 2015-09-01
# 336     2015-09        蘭陽分場      NaN    380.5 2015-09-01
# 360     2015-09       花蓮農改場        ＊       78 2015-09-01
# 72      2015-09      台東斑鳩分場      NaN     78.5 2015-09-01
# 192     2015-09       台中農改場      NaN      199 2015-09-01
# 96      2015-09       桃園農改場        ＊    112.5 2015-09-01
# 168     2015-09       農業試驗所      NaN    160.5 2015-09-01
# 144     2015-09       苗栗農改場      NaN      218 2015-09-01
# 312     2015-09      恆春畜試分所      NaN       41 2015-09-01
# 169     2015-10       農業試驗所      NaN      6.5 2015-10-01
# 145     2015-10       苗栗農改場        ＊     40.5 2015-10-01
# 73      2015-10      台東斑鳩分場      NaN       62 2015-10-01
# 193     2015-10       台中農改場      NaN       20 2015-10-01
# 241     2015-10        雲林分場      NaN       25 2015-10-01
# 265     2015-10       畜產試驗所      NaN      130 2015-10-01
# 49      2015-10       高雄農改場      NaN        0 2015-10-01
# 97      2015-10       桃園農改場        ＊       73 2015-10-01
# 25      2015-10       義竹工作站      NaN       10 2015-10-01
# 313     2015-10      恆春畜試分所      NaN       64 2015-10-01
# 121     2015-10       五峰工作站      NaN     43.5 2015-10-01
# 337     2015-10        蘭陽分場      NaN      421 2015-10-01
# 1       2015-10       茶業改良場        ＊    105.5 2015-10-01
# 361     2015-10       花蓮農改場      NaN     61.5 2015-10-01
# ..          ...         ...      ...      ...        ...
# 22      2017-07       茶業改良場      NaN    236.5 2017-07-01
# 262     2017-07        雲林分場      NaN      394 2017-07-01
# 358     2017-07        蘭陽分場      NaN    154.5 2017-07-01
# 190     2017-07       農業試驗所        ＊      354 2017-07-01
# 382     2017-07       花蓮農改場      NaN      155 2017-07-01
# 94      2017-07      台東斑鳩分場      NaN    250.5 2017-07-01
# 118     2017-07       桃園農改場        ＊     15.5 2017-07-01
# 46      2017-07       義竹工作站      NaN      505 2017-07-01
# 334     2017-07      恆春畜試分所        ＊      591 2017-07-01
# 142     2017-07       五峰工作站      NaN    457.5 2017-07-01
# 310     2017-07          東港      NaN        0 2017-07-01
# 214     2017-07       台中農改場      NaN        0 2017-07-01
# 166     2017-07       苗栗農改場      NaN      323 2017-07-01
# 286     2017-07       畜產試驗所      NaN    478.5 2017-07-01
# 359     2017-08        蘭陽分場      NaN       63 2017-08-01
# 191     2017-08       農業試驗所        ＊     77.5 2017-08-01
# 335     2017-08      恆春畜試分所        ＊      201 2017-08-01
# 311     2017-08          東港      NaN        0 2017-08-01
# 287     2017-08       畜產試驗所      NaN    152.5 2017-08-01
# 239     2017-08       溪頭營林區      NaN    127.5 2017-08-01
# 263     2017-08        雲林分場        ＊      141 2017-08-01
# 119     2017-08       桃園農改場        ＊        4 2017-08-01
# 143     2017-08       五峰工作站      NaN    129.5 2017-08-01
# 95      2017-08      台東斑鳩分場      NaN    223.5 2017-08-01
# 71      2017-08       高雄農改場      NaN      215 2017-08-01
# 47      2017-08       義竹工作站      NaN    145.5 2017-08-01
# 23      2017-08       茶業改良場        ＊        8 2017-08-01
# 215     2017-08       台中農改場      NaN       41 2017-08-01
# 167     2017-08       苗栗農改場        ＊       32 2017-08-01
# 383     2017-08       花蓮農改場        ＊    148.5 2017-08-01
#
# [384 rows x 5 columns]

# %%
df.describe()
# Out:
#        observeDate observatory dataLose  rainfall                 time
# count          384         384      124     384.0                  384
# unique          24          16        1     246.0                   24
# top        2015-09       苗栗農改場        ＊       0.0  2017-07-01 00:00:00
# freq            16          24      124      64.0                   16
# first          NaN         NaN      NaN       NaN  2015-09-01 00:00:00
# last           NaN         NaN      NaN       NaN  2017-08-01 00:00:00
