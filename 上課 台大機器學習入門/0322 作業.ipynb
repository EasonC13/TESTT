# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Noto Sans CJK TC')

# %%
df = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=7325&md5_url=c7884ece65970ed288258993eb8ed447')

# %%
df
# Out:
#    首站抵達地                           細分     2002       2003       2004  \
# 0   亞洲地區                 香港 Hong Kong  2418872  1,869,069  2,559,705
# 1   亞洲地區            大陸 Mainland China        1         44          -
# 2   亞洲地區                     日本 Japan   797460    731,330  1,051,954
# 3   亞洲地區         韓國 Korea,Republic of   120208    179,893    298,325
# 4   亞洲地區                新加坡 Singapore   190455    125,491    160,088
# 5   亞洲地區                馬來西亞 Malaysia   186791    121,267    180,883
# 6   亞洲地區                  泰國 Thailand   530945    392,414    422,189
# 7   亞洲地區              菲律賓 Philippines   128158     91,418    112,552
# 8   亞洲地區                 印尼 Indonesia   259610    251,284    283,757
# 9   亞洲地區                    汶淶 Brunei     5850      3,770      5,795
# 10  亞洲地區                   越南 Vietnam   225733    222,487    266,115
# 11  亞洲地區                     澳門 Macao  1269840    837,936  1,038,006
# 12  亞洲地區                   緬甸 Myanmar    19814     17,152     18,064
# ...

# %%
df['2003']
# Out:
# 0     1,869,069
# 1            44
# 2       731,330
# 3       179,893
# 4       125,491
# 5       121,267
# 6       392,414
# 7        91,418
# 8       251,284
# 9         3,770
# 10      222,487
# 11      837,936
# 12       17,152
# 13            -
# 14        9,190
# 15    4,852,745
# 16      479,264
# 17       95,226
# 18           11
# 19      574,501
# 20       24,245
# 21       20,524
# 22       16,367
# 23      105,885
# 24            2
# 25       23,432
# 26       21,754
# 27            7
# 28      212,216
# 29       70,679
# 30       24,819
# 31       28,388
# 32            0
# 33      123,886
# 34            0
# 35            0
# 36            0
# 37      159,724
# 38    5,923,072
# Name: 2003, dtype: object

# %%
ndf=np.array(df)

# %%
import locale
locale.setlocale(locale.LC_NUMERIC,'')
# Out:
# 'Chinese (Traditional)_Taiwan.950'

# %%
location = df.細分

# %%
column=df.columns

# %%
#這邊我無法使用 df.2017來取得資料，只好用for迴圈搞
df2=[0]
for i in range(len(ndf)):
    df2.append(ndf[i][17])

# %%
df2[1]
# Out:
# '1,773,252'

# %%
df2.remove(df2[0])

# %%
from pandas.core.frame import DataFrame
#df2=DataFrame(df2)
a=df2
df3=[]
df3=DataFrame(df3)
df3['人數']=a

# %%
df3
# Out:
#             人數
# 0    1,773,252
# 1    3,928,352
# 2    4,615,873
# 3      888,526
# 4      326,634
# 5      296,370
# 6      553,804
# 7      236,597
# 8      177,960
# 9          801
# 10     564,002
# 11     589,147
# 12      26,200
# 13      82,888
# 14     193,356
# 15  14,253,762
# 16     574,512
# 17     114,828
# 18       8,021
# 19     697,361
# 20      66,720
# 21      95,850
# 22      47,346
# 23      66,332
# 24      15,463
# 25      47,797
# 26      59,479
# 27      97,542
# 28     496,529
# 29     165,938
# 30       6,846
# 31       9,884
# 32       1,649
# 33     184,317
# 34       3,154
# 35      13,586
# 36      16,740
# 37       5,870
# 38  15,654,579

# %%
df3['地點']=df.細分

# %%
df3.head()
# Out:
#           人數                    地點
# 0  1,773,252          香港 Hong Kong
# 1  3,928,352     大陸 Mainland China
# 2  4,615,873              日本 Japan
# 3    888,526  韓國 Korea,Republic of
# 4    326,634         新加坡 Singapore

# %%
"Total" in np.array(df3['地點'])
# Out:
# False

# %%
df3['人數']=df3['人數'].apply(locale.atof)

# %%
df3['地區']=df.首站抵達地

# %%
df4=df3.sort_values(by=['人數'], ascending=False)

# %%
df4[:10].plot.bar(x='地點',y=['人數'])

# %%
res=[]  #移除TotAL的部分
for i in range(len(df4['地點'])):
    res.append('Total' not in df4['地點'][i] and 'Other' not in df4['地點'][i])

# %%
df5=df3[res]

# %%
df5=df5.sort_values(by=['人數'], ascending=False)

#plt.rcParams['savefig.dpi'] = 1000 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
df5[:10].plot.bar(x='地點',y=['人數'])
