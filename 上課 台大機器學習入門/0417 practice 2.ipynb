# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
def LossFunction(x):
    return  (x - 9) * (x - 4) * (x + 8) * (x + 7)

x = np.linspace(-10, 10, 100)
y = LossFunction(x)

plt.plot(x, y)

# %%
def dLossfunction(x):
    return 4 * x ** 3 + 6  * x ** 2 - 206 * x - 188

# %%
interact(dLossfunction,x=10.00)
# Out:
# interactive(children=(FloatSlider(value=10.0, description='x', max=30.0, min=-10.0), Output()), _dom_classes=(…
# <function __main__.dLossfunction(x)>
